# %% [markdown]
# # Data Science For Good
#
# ## Week 1 Notebook 0
#
# Welcome to Data Science For Good! In this course, we want to share with you the basic skills of coding in Python so that you can learn about data science and data analysis.
#
# In this notebook, we introduce you to how the Jupyter notebook works and how to get help. You can always come back to it when you need to review.

# %% [markdown]
# ## Cells
#
# The cells in a notebook can run the Python interpreter, which means it will interpret the code that you write.
#
# The default type of cells is `Code`, but you can change it to `Markdown` if you want to write text.
#
# `Code` cells have a prompt with square brackets \[ \] on its left, like the one below:

# %% [markdown]
# To execute, or run, the code in a cell, you can click the `Run` button from the commands above
#
# ![RunButton.jpg](attachment:RunButton.jpg)
#
# or press `Shift-Enter`.

# %%
# Click Run or press Shift+Enter in this cell
print("Hello!")

# %% [markdown]
# After a cell has been executed, you will see a number in the square brackets. The number tells you the order in which the cell was executed.
#
# **Try it Yourself!**
#
# In the cell below, type `print('Hello World!')` and run it.

# %%
# Type a greeting in Python

# %% [markdown]
# Congratulations! You have written your first piece of code in Python. You may have noticed that you can either use single quotation marks  `'  '` or double quotation marks `"  "` within the `print()` function. Python allows you to enter a string of characters with either set.

# %% [markdown]
# ### Starting and Stopping Kernel
#
# When we execute or run a cell, it also means that we are starting the notebook kernel.
#
# We also can stop the running code by clicking on the `Stop` button from the commands above.
#
# We can tell a code is currently running by looking at the circle in the top right corner of the notebook.
#
# A filled in circle means the code is running, while an empty circle means the code is not running.
#
# ![Run.png](attachment:Run.png)

# %% [markdown]
# ## Getting Help
#
# There is a `Help` menu at the top menu where you can find the documentation on using the notebook and Python.
#
# ![image.png](attachment:image.png)
#
#
# Do try out the User Interface Tour and notebook help.
#
#
# ### Tab Completion
#
# You can press the tab key to have the notebook present options for completing what you are typing:

# %%
# type the letter a then press the TAB key
# to view a list of commmands that start with 'a'

# %% [markdown]
# ### Getting help
#
# You can use the `help()` function to get information about a Python keyword or function.

# %%
# Run the line to view the documentation on the print function

help(print)

# %% [markdown]
# You can also position the cursor between the parentheses, () and press `Shift-TAB`

# %%
# place the cursor between the () and press Shift-TAB

print()

# %% [markdown]
# ### Comments
#
# The green lines that start with a `#` inside a code cell are comments - these are comments that the programmer might write to explain what they are doing.
#
# Commented lines are ignored by the Python interpreter.
#
# You can select multiple lines and hold on `Ctrl` and press the slash key ,`/` to toggle adding/removing comments on the selected lines.

# %%
# Select both lines below and press Ctrl and / together

a = 5
print(a)

# %% [markdown]
# ## Saving and Checkpoint
#
# The notebook that you are working on will be autosaved occasionally. We can save and checkpoint our notebook by click the `Save` button from the command above or press `Ctrl-S`. The notebook automatically displays the time we last checkpoint our code.
#
# To save your notebook in a different file name, click the `File` menu at the top menu, then select `Save as`.

# %% [markdown]
# Great! Do try out the other notebooks to familiarize yourself with them and you will be writing lots of code in no time.
